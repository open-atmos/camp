# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
cols = ['TrueA', 'ModelA', 'TrueB', 'ModelB', 'TrueC', 'ModelC', 'TrueH2O', 'ModelH2O']
df = pd.read_csv('/Users/kshores/Downloads/condensed_phase_photolysis_results.txt', 
            delim_whitespace=True, header=None,names=cols)

# %%
df
# Out:
#           TrueA        ModelA     TrueB        ModelB     TrueC    ModelC  \
# 0.0    1.000000  1.000000e+00  0.000000  0.000000e+00  0.000000  0.000000
# 1.0    0.951229  1.580253e-01  0.006305  4.061763e-02  0.004575  0.717434
# 2.0    0.904837  2.497200e-02  0.011425  1.283723e-02  0.017144  1.150779
# 3.0    0.860708  3.946208e-03  0.015539  3.042910e-03  0.036173  1.269822
# 4.0    0.818731  6.236007e-04  0.018802  6.411425e-04  0.060362  1.296624
# ...         ...           ...       ...           ...       ...       ...
# 96.0   0.008230  1.913365e-50  0.000573  2.223415e-49  1.287345  1.303435
# 97.0   0.007828  6.725361e-51  0.000545  7.875926e-50  1.288130  1.303435
# 98.0   0.007447  2.363923e-51  0.000519  2.789696e-50  1.288876  1.303435
# 99.0   0.007083  8.309044e-52  0.000493  9.880679e-51  1.289586  1.303435
# 100.0  0.006738  2.920578e-52  0.000469  3.499384e-51  1.290262  1.303435
#
#        TrueH2O  ModelH2O
# 0.0        2.3       2.3
# 1.0        2.3       2.3
# 2.0        2.3       2.3
# 3.0        2.3       2.3
# 4.0        2.3       2.3
# ...        ...       ...
# 96.0       2.3       2.3
# 97.0       2.3       2.3
# 98.0       2.3       2.3
# 99.0       2.3       2.3
# 100.0      2.3       2.3
#
# [101 rows x 8 columns]

# %%
fig, ax = plt.subplots(dpi=300)

df[['TrueA', 'ModelA', 'TrueB', 'ModelB', 'TrueC', 'ModelC']].plot(ax=ax, alpha=0.5)

ax.spines[:].set_visible(False)
ax.grid()
ax.tick_params(width=0)
