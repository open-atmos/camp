# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
cols = ['TrueA', 'ModelA', 'TrueB', 'ModelB', 'TrueC', 'ModelC', 'TrueH2O', 'ModelH2O']
df = pd.read_csv('/Users/kshores/Downloads/condensed_phase_photolysis_results.txt', 
            delim_whitespace=True, header=None,names=cols)

# %%
fig, ax = plt.subplots(dpi=300)

df[['TrueA', 'ModelA', 'TrueB', 'ModelB', 'TrueC', 'ModelC', 'TrueH2O', 'ModelH2O']].plot(ax=ax, alpha=0.5)

ax.spines[:].set_visible(False)
ax.grid()
ax.tick_params(width=0)

# %%
df
# Out:
#           TrueA  ModelA     TrueB        ModelB     TrueC        ModelC  \
# 0.0    1.000000     1.0  0.000000  0.000000e+00  0.000000  0.000000e+00
# 1.0    0.951229     1.0  0.006794  1.000000e-60  0.127139  1.000000e-60
# 2.0    0.904837     1.0  0.013257  1.000000e-60  0.248077  1.000000e-60
# 3.0    0.860708     1.0  0.019405  1.000000e-60  0.363116  1.000000e-60
# 4.0    0.818731     1.0  0.025253  1.000000e-60  0.472545  1.000000e-60
# ...         ...     ...       ...           ...       ...           ...
# 96.0   0.008230     1.0  0.138166  1.000000e-60  2.585416  1.000000e-60
# 97.0   0.007828     1.0  0.138222  1.000000e-60  2.586463  1.000000e-60
# 98.0   0.007447     1.0  0.138276  1.000000e-60  2.587458  1.000000e-60
# 99.0   0.007083     1.0  0.138326  1.000000e-60  2.588405  1.000000e-60
# 100.0  0.006738     1.0  0.138374  1.000000e-60  2.589305  1.000000e-60
#
#        TrueH2O  ModelH2O  TrueOrgA  ModelOrgA  TrueOrgB     ModelOrgB  \
# ...

# %%
plt.plot(np.arange(100), 1 * np.exp(-0.05 * np.arange(100)))
